# %%
import os
import datetime

import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fn = r'E:\001-selfrepo\emergencyDiffusionPlatform\tests\result.nc'
data = xr.open_dataarray(fn)
data
# Out:
# <xarray.DataArray 'C6H5' (time: 16, lat: 200, lon: 257, alt: 6)>
# [4934400 values with dtype=float64]
# Coordinates:
#   * time      (time) datetime64[ns] 2020-08-15T20:00:00 ... 2020-08-15T23:45:00
#   * alt       (alt) float64 0.0 10.0 20.0 50.0 100.0 200.0
#   * lon       (lon) float64 116.7 116.7 116.7 116.7 ... 117.0 117.0 117.0 117.0
#   * lat       (lat) float64 40.22 40.22 40.22 40.22 ... 40.46 40.46 40.46 40.46
#     quantile  float64 ...
# Attributes:
#     extent:   [115.90000153 117.90000148  39.31999969  41.31999965]

# %%
data.time
# Out:
# <xarray.DataArray 'time' (time: 16)>
# array(['2020-08-15T20:00:00.000000000', '2020-08-15T20:15:00.000000000',
#        '2020-08-15T20:30:00.000000000', '2020-08-15T20:45:00.000000000',
#        '2020-08-15T21:00:00.000000000', '2020-08-15T21:15:00.000000000',
#        '2020-08-15T21:30:00.000000000', '2020-08-15T21:45:00.000000000',
#        '2020-08-15T22:00:00.000000000', '2020-08-15T22:15:00.000000000',
#        '2020-08-15T22:30:00.000000000', '2020-08-15T22:45:00.000000000',
#        '2020-08-15T23:00:00.000000000', '2020-08-15T23:15:00.000000000',
#        '2020-08-15T23:30:00.000000000', '2020-08-15T23:45:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time      (time) datetime64[ns] 2020-08-15T20:00:00 ... 2020-08-15T23:45:00
#     quantile  float64 0.3
